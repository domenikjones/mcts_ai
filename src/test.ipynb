# %%
import gym

env = gym.make("Taxi-v3").env
env.render()

env.reset()
env.render()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-880affc42d8c> in <module>
#       1 import gym
#       2
# ----> 3 env = gym.make("Taxi-v3").env
#       4 env.render()
#       5
#
# ~/.local/share/virtualenvs/dojon_ai-J97T0knX/lib/python3.7/site-packages/gym/envs/registration.py in make(id, **kwargs)
#
# ~/.local/share/virtualenvs/dojon_ai-J97T0knX/lib/python3.7/site-packages/gym/envs/registration.py in make(self, path, **kwargs)
#
# ~/.local/share/virtualenvs/dojon_ai-J97T0knX/lib/python3.7/site-packages/gym/envs/registration.py in make(self, **kwargs)
#
# ~/.local/share/virtualenvs/dojon_ai-J97T0knX/lib/python3.7/site-packages/gym/envs/registration.py in load(name)
#
# /usr/local/opt/python/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
# ...

# %%
from gym import envs
for t in envs.registry.all():
    print(t)
# Out:
# EnvSpec(Copy-v0)
# EnvSpec(RepeatCopy-v0)
# EnvSpec(ReversedAddition-v0)
# EnvSpec(ReversedAddition3-v0)
# EnvSpec(DuplicatedInput-v0)
# EnvSpec(Reverse-v0)
# EnvSpec(CartPole-v0)
# EnvSpec(CartPole-v1)
# EnvSpec(MountainCar-v0)
# EnvSpec(MountainCarContinuous-v0)
# EnvSpec(Pendulum-v0)
# EnvSpec(Acrobot-v1)
# EnvSpec(LunarLander-v2)
# EnvSpec(LunarLanderContinuous-v2)
# EnvSpec(BipedalWalker-v3)
# EnvSpec(BipedalWalkerHardcore-v3)
# EnvSpec(CarRacing-v0)
# EnvSpec(Blackjack-v0)
# EnvSpec(KellyCoinflip-v0)
# EnvSpec(KellyCoinflipGeneralized-v0)
# EnvSpec(FrozenLake-v0)
# EnvSpec(FrozenLake8x8-v0)
# EnvSpec(CliffWalking-v0)
# EnvSpec(NChain-v0)
# EnvSpec(Roulette-v0)
# EnvSpec(Taxi-v3)
# EnvSpec(GuessingGame-v0)
# EnvSpec(HotterColder-v0)
# EnvSpec(Reacher-v2)
# EnvSpec(Pusher-v2)
# EnvSpec(Thrower-v2)
# EnvSpec(Striker-v2)
# EnvSpec(InvertedPendulum-v2)
# EnvSpec(InvertedDoublePendulum-v2)
# EnvSpec(HalfCheetah-v2)
# EnvSpec(HalfCheetah-v3)
# EnvSpec(Hopper-v2)
# EnvSpec(Hopper-v3)
# ...
